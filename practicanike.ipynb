# %%
#Saturdays.AI, Practica Pandas, Xochitl Arroyo 
import numpy as np
import pandas as pd
def quality_report(data):

    """This method will do a basic data quality report for a data frame"""
        
    if (type(data) != pd.core.frame.DataFrame):
        raise TypeError("Data must be pandas.core.frame.DataFrame")
    else: 
        columns = list(data.columns.values)
        data_type = pd.DataFrame(data.dtypes, columns=['Data type'])
        missing_data = pd.DataFrame(
        data.isnull().sum(), columns=['missing values'])
        present_data = pd.DataFrame(data.count(), columns=['present values'])
        unique_values = pd.DataFrame(columns=['unique values'])
        minimum_values = pd.DataFrame(columns=['minimum values'])
        max_values = pd.DataFrame(columns=['maximun values'])
        
        for i in columns:
            unique_values.loc[i] = [data[i].nunique()]
            try:
                minimum_values.loc[i] = [data[i].min()]
                max_values.loc[i] = [data[i].max()]
            except:
                pass
        
        DQ_report = data_type.join(missing_data).join(present_data).join(
        unique_values).join(minimum_values).join(max_values)
    
    return DQ_report
csv_original = 'DataSetNike.csv'
dataset_original = pd.read_csv(csv_original, encoding='latin-1', low_memory=False)
df = pd.DataFrame(dataset_original, columns=['Material', 'Date', 'Units'])
df.columns = ['Codigo','Date', 'Units']
df.dropna()
df=df[df.Units >=1]
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.strftime('%m')
df['Year'] = df['Date'].dt.year
df.set_index(['Month','Year'])
print(df.dtypes)
table = df.pivot_table(index=['Codigo','Year'], columns='Month', values='Units', aggfunc=np.sum, fill_value=0)
table.columns = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']
print(table)
quality_report(table)
# Out:
# Codigo            object
# Date      datetime64[ns]
# Units              int64
# Month             object
# Year               int64
# dtype: object
#                  Enero  Febrero  Marzo  Abril  Mayo  Junio  Julio  Agosto  \
# Codigo     Year
# 145698-JAR 2018      0        0      0      0     0      0      0       0
# 145699-SAA 2018      0        0      0      0     0      0      0       8
# 145700-BAJ 2018     99        2      2      0     0      0      0       0
# 145701-KAS 2017      0        0      0      0     0      0      0       0
# 145702-TAB 2017      0        0      0      0     0      0      0       0
# 145703-CAK 2017      0        0      0      0     0      0      0       0
#            2018      0        0      0      0     0      0      2       0
# 145704-LAT 2018      0       61     37      8     1      5      4       0
# 145705-UAC 2017      0        0      0      0     0      0      0       0
# 145706-DAL 2017      0        0      0      0     0      0      0       0
# 145707-MAU 2017      0        0      0      0     0      0      0       0
# 145708-VAD 2017      0        0      0      0     0      0      0       0
#            2018      3        0      0      0     0      0      0       0
# 145709-EAM 2018      0        0      0      0     0      0      0       0
# 145710-NAV 2017      0        0      0      0     0      0      0       0
#            2018      0        2      1      4     6      6      4       0
# 145711-WAE 2018      0        0      6      0     0      0      0       0
# 145712-FAN 2017      0        0      0      0     0      0      0       0
#            2018      0        0      1      0     0      0      0       0
# 145713-OAW 2018      0        0      1      0     0      0      0       0
# 145714-XAF 2017      0        0      0      0     0      0      0       0
#            2018      2        0      0      0     1      0      0       0
# 145715-GAO 2017      0        0      0      0     0      0      0       0
#            2018      2        0      3      0     0      1      0       0
# 145716-PAX 2018      0       12      9      0     0      0      0       0
# 145717-YAG 2018      0       96      4      0     0     10     40      50
# 145718-HAP 2018      0        5      1     23    39      8      6       0
# 145719-QAY 2017      0        0      0      0     0      0      0       0
#            2018      7        0      0      0     0      2      7       8
# 145720-ZAH 2018      0        0      0      0     0      0      0     103
# ...                ...      ...    ...    ...   ...    ...    ...     ...
# 995691-YZG 2018      1        1      0      0     0      0      0       0
# 995700-HZP 2018      3       34     47     33    17      0      0       0
# 995709-QZY 2018      4        0      0      0     2      0      0       0
# 995718-ZZH 2017      0        0      0      0     0      0      0       0
#            2018      0        0      0      0     1      0      2       0
# 995727-IZQ 2017      0        0      0      0     0      0      0       0
# 995736-RZZ 2017      0        0      0      0     0      0      0       0
#            2018      3        0      0      5     1      1      1       0
# 995745-AZI 2017      0        0      0      0     0      0      0       0
# 995754-JZR 2017      0        0      0      0     0      0      0       0
# 995763-SZA 2017      0        0      0      0     0      0      0       0
# 995772-BZJ 2017      0        0      0      0     0      0      0       0
#            2018      9        1      8      0     0      0      1       0
# 995781-KZS 2017      0        0      0      0     0      0      0       0
#            2018      4        0      0      3     4      2      5       2
# 995790-TZB 2017      0        0      0      0     0      0      0       0
#            2018    137       79     94     14    42     15     45      51
# 995799-CZK 2018      0        0      0      0     4      1      2       1
# 995808-LZT 2018      0        0      0      0     0      0      0       0
# 995817-UZC 2017      0        0      0      0     0      0      0       0
#            2018      0        0      2      2     4      2      2       3
# 995826-DZL 2018      0        0      0      0     0      2     23      15
# 995835-MZU 2018      0        0      0      0     0      0      0       0
# 995844-VZD 2017      0        0      0      0     0      0      0       0
#            2018     10        2      3      4     4      0      2       4
# 995853-EZM 2018      0       60      0      0     0      0      0       0
# 995862-NZV 2017      0        0      0      0     0      0      0       0
#            2018      6        0      1      4     2      0      0       0
# 995871-WZE 2018     30       49      0      0     0      0      0       0
# 995880-FZN 2018      0        0      0      0     0      0      1       4
#
#                  Septiembre  Octubre  Noviembre  Diciembre
# Codigo     Year
# 145698-JAR 2018           1        0          0          0
# 145699-SAA 2018           1        0          0          0
# 145700-BAJ 2018           0        0          0          0
# 145701-KAS 2017           0        0          1          0
# 145702-TAB 2017           0       14          4          0
# 145703-CAK 2017           0        1          7          1
#            2018           0        0          0          0
# 145704-LAT 2018           0        0          0          0
# 145705-UAC 2017           1        0          0          0
# 145706-DAL 2017           0        0         35          0
# 145707-MAU 2017          16        9         25          2
# 145708-VAD 2017           2        0          0          1
#            2018           0        0          0          0
# 145709-EAM 2018           1        0          0          0
# 145710-NAV 2017           1        1          3          4
#            2018           0        0          0          0
# 145711-WAE 2018           0        0          0          0
# 145712-FAN 2017           0        1          2          0
#            2018           0        0          0          0
# 145713-OAW 2018           0        0          0          0
# 145714-XAF 2017           0        0         43         61
#            2018           0        0          0          0
# 145715-GAO 2017           0        0         18         74
#            2018           0        0          0          0
# 145716-PAX 2018           0        0          0          0
# 145717-YAG 2018           0        0          0          0
# 145718-HAP 2018           0        0          0          0
# 145719-QAY 2017           8        3         24          6
#            2018           4        0          0          0
# 145720-ZAH 2018          96        0          0          0
# ...                     ...      ...        ...        ...
# 995691-YZG 2018           0        0          0          0
# 995700-HZP 2018           0        0          0          0
# 995709-QZY 2018           0        0          0          0
# 995718-ZZH 2017           1        3          3          0
#            2018           0        0          0          0
# 995727-IZQ 2017           0        1          0          0
# 995736-RZZ 2017           1        3         10          1
#            2018           0        0          0          0
# 995745-AZI 2017           3        4          0          0
# 995754-JZR 2017           1        0          0          0
# 995763-SZA 2017           2        2          0          0
# 995772-BZJ 2017           0        0          0          1
#            2018           4        0          0          0
# 995781-KZS 2017           0        0          0          1
#            2018           0        0          0          0
# 995790-TZB 2017           0        0          0          5
#            2018          29        0          0          0
# 995799-CZK 2018           2        0          0          0
# 995808-LZT 2018           1        0          0          0
# 995817-UZC 2017           0        0          0          4
#            2018           2        0          0          0
# 995826-DZL 2018           3        0          0          0
# 995835-MZU 2018         143        0          0          0
# 995844-VZD 2017           0        0          0          9
#            2018           1        0          0          0
# 995853-EZM 2018           0        0          0          0
# 995862-NZV 2017           0        0          0         16
#            2018           0        0          0          0
# 995871-WZE 2018          63        0          0          0
# 995880-FZN 2018           2        0          0          0
#
# [7877 rows x 12 columns]
#            Data type  missing values  present values unique values  \
# Enero          int64               0            7877           118
# Febrero        int64               0            7877            99
# Marzo          int64               0            7877            94
# Abril          int64               0            7877            94
# Mayo           int64               0            7877            91
# Junio          int64               0            7877            56
# Julio          int64               0            7877            71
# Agosto         int64               0            7877            77
# Septiembre     int64               0            7877            80
# Octubre        int64               0            7877            48
# Noviembre      int64               0            7877           115
# Diciembre      int64               0            7877           121
#
#            minimum values maximun values
# Enero                   0            155
# Febrero                 0            169
# Marzo                   0            148
# Abril                   0            191
# Mayo                    0            123
# Junio                   0             88
# Julio                   0            106
# Agosto                  0            136
# Septiembre              0            181
# Octubre                 0             90
# Noviembre               0            250
# Diciembre               0            173
